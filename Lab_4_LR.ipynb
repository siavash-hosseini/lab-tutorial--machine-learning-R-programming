# %% [markdown]
# # Lab 4
#
# #ESOF 5050/0151
#
# In this Lab, we will cover
#
#
# - Creating training and test data with 80:20: sample(), set the seed using set.seed() so the samples can be recreated for future use.
# - Statistical analysis: build a linear regression model on the traning data and validate it on the test set. Describing the results using plots and tables. Some useful functions: lm(), summary(), predict()

# %% [markdown]
# # Initial Setup

# %% [markdown]
# Upload the provided files to the Session Storage
#   - `income.csv`

# %% [markdown]
# # Task 1

# %% [markdown]
# **Task**: Import `income.csv` as a dataframe.

# %%
# Your code goes here...

# %% [markdown]
# # Task 2

# %% [markdown]
# > Creating training and test data with 80:20: sample(), set the seed using set.seed() so the samples can be recreated for future use.

# %%
# Your code goes here.
# First, select the size of the sample. Notice it needs to be an integer.
## 80% of the sample size
 sample_size <-

# %%
# Second, Let's set the seed to make your partition reproducible

# %%
# Your code goes here.
# Third, Sample the indexes that will be used to select the samples from the dataframe. Tip, use the `sample` function.
 indexes <- sample()

# %%
# Your code goes here.
# Finally, now use the sequence of indexes to select the training and testing sampless.
 train <- 
 test <-

# %% [markdown]
# # Task 3

# %% [markdown]
# The `lm` function can be used to create a linear model. In order to do so, a `formula` needs to be defined.

# %% [markdown]
# **Task**: Read the help of the `lm` function

# %%
?lm

# %% [markdown]
# The line below creates a model that predicts the `Income` using the `Age` field

# %%
colnames(df)
# Out:
# [1] "ID"        "Income"    "Age"       "Education" "Gender"

# %%
# model1 <- lm(Income ~ Age, train)
modle1 <- lm(Income ~ Age, df)

# %% [markdown]
# **Task**: Analyze this model with the `summary` function

# %%
# Your code goes here

summary(modle1)
# Out:
# Call:
# lm(formula = Income ~ Age, data = df)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -43.448  -8.496   0.529   8.613  41.679
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 32.21949    1.01915   31.61   <2e-16 ***
# Age          1.00423    0.02209   45.47   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 12.97 on 1498 degrees of freedom
# Multiple R-squared:  0.5799,	Adjusted R-squared:  0.5796
# F-statistic:  2067 on 1 and 1498 DF,  p-value: < 2.2e-16

# %% [markdown]
# # Task 4

# %% [markdown]
# **Task**: Create a linear model that predicts `Income` based on `Age` and `Education`

# %%
# Your code goes here

# %% [markdown]
# **Task**: Analyze model 2 with summary

# %%
# Your code goes here.

summary(modle2)
# Out:
# Call:
# lm(formula = Income ~ Age + Education, data = train)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -37.264  -7.967   0.209   8.053  37.624
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  7.47091    2.17831    3.43 0.000625 ***
# Age          1.00035    0.02352   42.53  < 2e-16 ***
# Education    1.70677    0.13044   13.09  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 12.21 on 1197 degrees of freedom
# Multiple R-squared:  0.6264,	Adjusted R-squared:  0.6258
# F-statistic:  1004 on 2 and 1197 DF,  p-value: < 2.2e-16

# %% [markdown]
# # Task 5

# %% [markdown]
# **Task**: Create a model that predicts `Income` based on all other Input fields.

# %%
# Your code goes here.

# %% [markdown]
# **Task**: Check model with `summary`

# %%
# Your code goes here.

summary(modle3)
# Out:
# Call:
# lm(formula = Income ~ Age + Education + Gender, data = train)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -37.445  -8.080   0.241   8.099  37.429
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  7.67772    2.21308   3.469  0.00054 ***
# Age          0.99979    0.02355  42.447  < 2e-16 ***
# Education    1.70712    0.13048  13.084  < 2e-16 ***
# Gender      -0.37709    0.70582  -0.534  0.59326
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 12.21 on 1196 degrees of freedom
# Multiple R-squared:  0.6265,	Adjusted R-squared:  0.6256
# F-statistic: 668.7 on 3 and 1196 DF,  p-value: < 2.2e-16

# %% [markdown]
# **Question**: Does it make sense to use ID in the linear model? Justify your answer.

# %% [markdown]
# **Task**: Calculate the prediction of for the test set using `model3`.

# %%
# Your code goes here. Tip, use the predict function

# %%
result3 <- predict(..., ...)

# %% [markdown]
# # Task 6
#
# Calculating Error Metrics

# %%
#1. MEAN ABSOLUTE PERCENTAGE ERROR (MAPE)
MAPE = function(y_actual,y_predict){
  mean(abs((y_actual-y_predict)/y_actual))*100
}
 
#2. R SQUARED error metric -- Coefficient of Determination
RSQUARE = function(y_actual,y_predict){
  cor(y_actual,y_predict)^2
}

# %% [markdown]
# Calculate the MAPE and $R^2$ metrics of model3 for the test set.

# %%
# Your code goes here.

MAPE(test$Income,result3)
RSQUARE(test$Income,result3)
# Out:
# [1] 13.75221
# [1] 0.6750467
